# %%
import pandas as pd

# %%
file = pd.read_csv('F:\\datasets\\mushrooms.csv')
df = file.copy()
df.sample(10)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 4292     p         x           f         y       f    f               f
# 4895     p         x           f         y       f    f               f
# 1570     e         f           f         n       f    n               f
# 4333     p         x           y         g       f    f               f
# 476      e         x           f         n       f    n               f
# 6072     p         f           s         n       f    s               f
# 6015     p         f           y         e       f    f               f
# 3753     p         x           s         g       f    c               f
# 5863     e         f           s         n       t    n               f
# 4228     p         x           f         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 4292            c         b          p  ...                        k
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
for col in df.columns :
    print(col)
    print(len(set(df[col])))
# Out:
# class
# 2
# cap-shape
# 6
# cap-surface
# 4
# cap-color
# 10
# bruises
# 2
# odor
# 9
# gill-attachment
# 2
# gill-spacing
# 2
# gill-size
# 2
# gill-color
# 12
# stalk-shape
# 2
# stalk-root
# 5
# stalk-surface-above-ring
# 4
# stalk-surface-below-ring
# 4
# stalk-color-above-ring
# 9
# stalk-color-below-ring
# 9
# veil-type
# 1
# veil-color
# 4
# ring-number
# 3
# ring-type
# 5
# spore-print-color
# 9
# population
# 6
# habitat
# 7

# %%
label = df['class']
df = df.drop(['class'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
lst = []
for i in df.columns :
    x = pd.DataFrame(encoder.fit_transform(df[i]),columns=[i])
    lst.append(x)
encoded_df = pd.concat(lst,axis=1)
encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 8124 non-null   int32
#  1   cap-surface               8124 non-null   int32
#  2   cap-color                 8124 non-null   int32
#  3   bruises                   8124 non-null   int32
#  4   odor                      8124 non-null   int32
#  5   gill-attachment           8124 non-null   int32
#  6   gill-spacing              8124 non-null   int32
#  7   gill-size                 8124 non-null   int32
#  8   gill-color                8124 non-null   int32
#  9   stalk-shape               8124 non-null   int32
#  10  stalk-root                8124 non-null   int32
#  11  stalk-surface-above-ring  8124 non-null   int32
#  12  stalk-surface-below-ring  8124 non-null   int32
#  13  stalk-color-above-ring    8124 non-null   int32
# ...

# %%
encoded_df.sample(10)
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 6543          2            3          2        0     7                1
# 1688          5            3          4        1     5                1
# 5578          5            3          1        0     5                1
# 6533          5            3          2        0     2                1
# 5772          5            2          0        1     2                1
# 2295          2            2          8        0     5                1
# 1898          2            2          4        0     5                1
# 6959          3            2          4        0     2                1
# 4235          2            3          3        0     2                1
# 4483          2            3          3        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 6543             0          1           0            1  ...
# ...

# %%
encoded_label = pd.DataFrame(encoder.fit_transform(label),columns=['class'])

# %%
from sklearn.model_selection import train_test_split
xtr , xts , ytr , yts = train_test_split(encoded_df,encoded_label)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_xtr = pd.DataFrame(scaler.fit_transform(xtr),columns=df.columns)
scaled_xts = pd.DataFrame(scaler.fit_transform(xts),columns=df.columns)

# %%
from sklearn.svm import LinearSVC
alg = LinearSVC()
alg.fit(scaled_xtr,ytr)
alg.score(scaled_xtr,ytr)*100
# Out:
# C:\Users\pouria_z\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 95.33891350730346

# %%
alg.score(scaled_xts,yts)*100
# Out:
# 95.22402757262432

# %%
scaled_df = pd.DataFrame(scaler.fit_transform(encoded_df),columns=encoded_df.columns)
alg.fit(scaled_df,encoded_label)
alg.score(scaled_df,encoded_label)*100
# Out:
# C:\Users\pouria_z\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 95.16248153618906
